# %%
pip install bs4

# %%
pip install requests

# %%
import requests

from bs4 import BeautifulSoup

# %%
url='https://www.mysmartprice.com/accessories/pricelist/power-banks-price-list-in-india.html'

# %%
response=requests.get(url)

response
# Out:
# <Response [200]>

# %%
Power_bank=BeautifulSoup(response.text)

Power_bank
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml"><head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/><meta content="en-uk, english" name="language"/><title>Power Banks Price in India 2022 | Power Banks Price List in India 2022 19th March</title><!--zz--> <title>  Price in India  2022-03-19</title><!--zz--> <link href="/osd.xml" rel="search" title="MySmartPrice" type="application/opensearchdescription+xml"/><style>/**
#  * Table of contents:
#  * msp_common_critical.css
#  * Generated: 2022-03-14 05:08:19
#  */
#
#
# /* Filename: msp_common_critical.css */
# ...

# %%
name=Power_bank.select('.prdct-item__name')

name
# Out:
# [<a class="prdct-item__name" href="https://www.mysmartprice.com/accessories/xiaomi-mi-power-bank-3i-10000mah-power-bank-msf582452" target="_blank">       Xiaomi Mi Power Bank 3i 10000mAh Power Bank
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/accessories/xiaomi-mi-pb10izm-10000mah-power-bank-msf567557" target="_blank">       Xiaomi Mi PB10IZM 10000mAh Power Bank
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/accessories/xiaomi-mi-power-bank-3i-20000mah-power-bank-msf582453" target="_blank">       Xiaomi Mi Power Bank 3i 20000mAh Power Bank
#                      </a>,
#  <a class="prdct-item__name" href="https://www.mysmartprice.com/accessories/ambrane-p-1122-10000mah-power-bank-msf567988" target="_blank">       Ambrane P-1122 10000mAh Power Bank
#                      </a>,
# ...

# %%
Powerbank_name=[]

# %%
for item in name:
  Powerbank_name.append(item.text)
  link="www.mysmartprice.com"+item["href"]

# %%
Powerbank_name
# Out:
# ['       Xiaomi Mi Power Bank 3i 10000mAh Power Bank\n                    ',
#  '       Xiaomi Mi PB10IZM 10000mAh Power Bank\n                    ',
#  '       Xiaomi Mi Power Bank 3i 20000mAh Power Bank\n                    ',
#  '       Ambrane P-1122 10000mAh Power Bank\n                    ',
#  '       Ambrane P-1111 10000mAh Power Bank\n                    ',
#  '       Lenovo Pa10400 10400mAh Power Bank\n                    ',
#  '       Realme Power Bank 2 10000mAh Power Bank\n                    ',
#  '       Ambrane PP-150 15000mAh Power Bank\n                    ',
#  '       Xiaomi PB200LZM 20000mAh Power Bank\n                    ',
#  '       Xiaomi PB100LZM 10000mAh Power Bank\n                    ',
#  '       OPPO Power Bank 2 10000mAh Power Bank\n                    ',
#  '       Samsung EB-P3000BSNGIN 10000mAh Power Bank\n                    ',
#  '       Lionix M-15K 15000mAh Power Bank\n                    ',
# ...

# %%
price=Power_bank.select(".prdct-item__prc-val")

price
# Out:
# [<span class="prdct-item__prc-val">899</span>,
#  <span class="prdct-item__prc-val">899</span>,
#  <span class="prdct-item__prc-val">1,499</span>,
#  <span class="prdct-item__prc-val">499</span>,
#  <span class="prdct-item__prc-val">699</span>,
#  <span class="prdct-item__prc-val">2,999</span>,
#  <span class="prdct-item__prc-val">999</span>,
#  <span class="prdct-item__prc-val">799</span>,
#  <span class="prdct-item__prc-val">1,298</span>,
#  <span class="prdct-item__prc-val">798</span>,
#  <span class="prdct-item__prc-val">1,099</span>,
#  <span class="prdct-item__prc-val">1,736</span>,
#  <span class="prdct-item__prc-val">594</span>,
#  <span class="prdct-item__prc-val">699</span>,
#  <span class="prdct-item__prc-val">2,499</span>,
#  <span class="prdct-item__prc-val">399</span>,
#  <span class="prdct-item__prc-val">710</span>,
#  <span class="prdct-item__prc-val">1,599</span>,
#  <span class="prdct-item__prc-val">899</span>,
#  <span class="prdct-item__prc-val">798</span>,
# ...

# %%
Powerbank_price=[]

# %%
for item in price:
  Powerbank_price.append(item.text)

Powerbank_price
# Out:
# ['899',
#  '899',
#  '1,499',
#  '499',
#  '699',
#  '2,999',
#  '999',
#  '799',
#  '1,298',
#  '798',
#  '1,099',
#  '1,736',
#  '594',
#  '699',
#  '2,499',
#  '399',
#  '710',
#  '1,599',
#  '899',
#  '798',
#  '1,599',
#  '699',
#  '599',
#  '999',
#  '649',
#  '749',
#  '1,099',
#  '767',
#  '799',
#  '34,999',
#  '4,499',
#  '800',
#  '1,199',
#  '1,249',
#  '1,157',
#  '1,299',
#  '825',
#  '975',
#  '1,497',
#  '899',
#  '715',
#  '1,035',
#  '485',
#  '715',
#  '799',
#  '675',
#  '499',
#  '699']

# %%
ratings=Power_bank.select(".rtng-star__inr")

ratings
# Out:
# [<div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 64%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 74%;">
#  </div>, <div class="rtng-star__inr" style="width: 0%;">
#  </div>, <div class="rtng-star__inr" style="width: 74%;">
# ...
